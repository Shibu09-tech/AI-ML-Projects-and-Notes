# %% [markdown]
# <a href="https://colab.research.google.com/github/Shibu09-tech/AI-ML-Projects-and-Notes/blob/main/Lab4_Predictive_Maintenance_from_Sensor_Logs/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
